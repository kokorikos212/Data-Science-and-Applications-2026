# %% [markdown]
# Για τις ανάγκες της προκαταρκτικής αυτής εργασίας έχουν δημιουργηθεί πακέτα κώδικα που χρησιμοποιούνται ως βιβλιοθήκες στη ροή του notebook.

# %%
import importlib
import DatasetBuilder
import visualisation_mod
import pandas as pd

# Force a fresh load of both modules
importlib.reload(DatasetBuilder)
importlib.reload(visualisation_mod)

from DatasetBuilder import MultimodalDatasetFactory, MultimodalUniverseFactory
from visualisation_mod import UniverseVisualizer

DATA_ROOT = "/content/drive/MyDrive/Data_science_and_applications"
factory = MultimodalUniverseFactory(base_path=DATA_ROOT)
print("✓ Modules synced and ready.")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/thinpan/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/thinpan/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/thinpan/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/thinpan/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/thinpan/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/thinpan/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/thinpan/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/thinpan/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/thinpan/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_17750/2768156300.py", line 2, in <module>
#     import DatasetBuilder
#   File "/home/thinpan/Desktop/Final_Year/εαρινο/Data_Science/Data-Science-and-Applications-2026/our_work/base/src/DatasetBuilder.py", line 1, in <module>
#     from astropy.coordinates import SkyCoord
#   File "/usr/local/lib/python3.10/dist-packages/astropy/__init__.py", line 21, in <module>
#     from . import config as _config
#   File "/usr/local/lib/python3.10/dist-packages/astropy/config/__init__.py", line 8, in <module>
#     from .configuration import *
#   File "/usr/local/lib/python3.10/dist-packages/astropy/config/configuration.py", line 24, in <module>
#     from astropy.utils import find_current_module, silence
#   File "/usr/local/lib/python3.10/dist-packages/astropy/utils/__init__.py", line 17, in <module>
#     from .codegen import *
#   File "/usr/local/lib/python3.10/dist-packages/astropy/utils/codegen.py", line 12, in <module>
#     from .introspection import find_current_module
#   File "/usr/local/lib/python3.10/dist-packages/astropy/utils/introspection.py", line 14, in <module>
#     from astropy.utils.decorators import deprecated_renamed_argument
#   File "/usr/local/lib/python3.10/dist-packages/astropy/utils/decorators.py", line 13, in <module>
#     from .exceptions import (
#   File "/usr/local/lib/python3.10/dist-packages/astropy/utils/exceptions.py", line 11, in <module>
#     from erfa import ErfaError, ErfaWarning  # noqa: F401
#   File "/usr/local/lib/python3.10/dist-packages/erfa/__init__.py", line 5, in <module>
#     from .version import version as __version__  # noqa
#   File "/usr/local/lib/python3.10/dist-packages/erfa/version.py", line 25, in <module>
#     from . import ufunc
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import importlib
# ----> 2 import DatasetBuilder
#       3 import visualisation_mod
#       4 import pandas as pd
#
# File ~/Desktop/Final_Year/εαρινο/Data_Science/Data-Science-and-Applications-2026/our_work/base/src/DatasetBuilder.py:1
# ----> 1 from astropy.coordinates import SkyCoord
#       2 import astropy.units as u
#       3 import pandas as pd
#
# File /usr/local/lib/python3.10/dist-packages/astropy/__init__.py:21
#      14 # The location of the online documentation for astropy
#      15 # This location will normally point to the current released version of astropy
#      16 online_docs_root = "https://docs.astropy.org/en/{}/".format(
#      17     "latest" if "dev" in __version__ else f"v{__version__}"
#      18 )
# ---> 21 from . import config as _config
#      24 class Conf(_config.ConfigNamespace):
#      25     """
#      26     Configuration parameters for `astropy`.
#      27     """
#
# File /usr/local/lib/python3.10/dist-packages/astropy/config/__init__.py:8
#       1 # Licensed under a 3-clause BSD style license - see LICENSE.rst
#       3 """
#       4 This module contains configuration and setup utilities for the
#       5 Astropy project.
#       6 """
# ----> 8 from .configuration import *
#       9 from .paths import *
#
# File /usr/local/lib/python3.10/dist-packages/astropy/config/configuration.py:24
#      21 from warnings import warn
#      23 from astropy.extern.configobj import configobj, validate
# ---> 24 from astropy.utils import find_current_module, silence
#      25 from astropy.utils.decorators import deprecated
#      26 from astropy.utils.exceptions import AstropyDeprecationWarning, AstropyWarning
#
# File /usr/local/lib/python3.10/dist-packages/astropy/utils/__init__.py:17
#       1 # Licensed under a 3-clause BSD style license - see LICENSE.rst
#       2 """
#       3 This subpackage contains developer-oriented utilities used by Astropy.
#       4
#    (...)
#      14
#      15 """
# ---> 17 from .codegen import *
#      18 from .decorators import *
#      19 from .introspection import *
#
# File /usr/local/lib/python3.10/dist-packages/astropy/utils/codegen.py:12
#       9 import re
#      10 import textwrap
# ---> 12 from .introspection import find_current_module
#      14 __all__ = ["make_function_with_signature"]
#      17 _ARGNAME_RE = re.compile(r"^[A-Za-z][A-Za-z_]*")
#
# File /usr/local/lib/python3.10/dist-packages/astropy/utils/introspection.py:14
#      10 from importlib import metadata
#      12 from packaging.version import Version
# ---> 14 from astropy.utils.decorators import deprecated_renamed_argument
#      16 __all__ = ["resolve_name", "minversion", "find_current_module", "isinstancemethod"]
#      18 __doctest_skip__ = ["find_current_module"]
#
# File /usr/local/lib/python3.10/dist-packages/astropy/utils/decorators.py:13
#      10 import warnings
#      11 from inspect import signature
# ---> 13 from .exceptions import (
#      14     AstropyDeprecationWarning,
#      15     AstropyPendingDeprecationWarning,
#      16     AstropyUserWarning,
#      17 )
#      19 __all__ = [
#      20     "classproperty",
#      21     "deprecated",
#    (...)
#      26     "sharedmethod",
#      27 ]
#      29 _NotFound = object()
#
# File /usr/local/lib/python3.10/dist-packages/astropy/utils/exceptions.py:11
#       2 """
#       3 This module contains errors/exceptions and warnings of general use for
#       4 astropy. Exceptions that are specific to a given subpackage should *not* be
#       5 here, but rather in the particular subpackage.
#       6 """
#       8 # TODO: deprecate these.  This cannot be trivially done with
#       9 # astropy.utils.decorators.deprecate, since that module needs the exceptions
#      10 # here, leading to circular import problems.
# ---> 11 from erfa import ErfaError, ErfaWarning  # noqa: F401
#      13 __all__ = [
#      14     "AstropyWarning",
#      15     "AstropyUserWarning",
#    (...)
#      20     "NoValue",
#      21 ]
#      24 class AstropyWarning(Warning):
#
# File /usr/local/lib/python3.10/dist-packages/erfa/__init__.py:5
#       1 # Licensed under a 3-clause BSD style license - see LICENSE.rst
#       2
#       3 # Import version first, as this gives a more useful error message
#       4 # if a system liberfa is too old.
# ----> 5 from .version import version as __version__  # noqa
#       6 from .core import *  # noqa
#       7 from .ufunc import (dt_eraASTROM, dt_eraLDBODY, dt_eraLEAPSECOND,  # noqa
#       8                     dt_pv, dt_sign, dt_type, dt_ymdf, dt_hmsf, dt_dmsf)
#
# File /usr/local/lib/python3.10/dist-packages/erfa/version.py:25
#      22 # Set the version numbers a bit indirectly, so that Sphinx can pick up
#      23 # up the docstrings and list the values.
#      24 try:
# ---> 25     from . import ufunc
#      26 except ImportError as exc:
#      27     # If compiled to use a system liberfa, that library can be too old, and
#      28     # miss functions that are available in newer liberfa. If so, we should
#      29     # bail since nothing will work, but let's try to give a more informative
#      30     # error message.
#      31     try:
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# Στο πρώτο αυτό notebook της συνολικής εργασίας για λογαριασμό του μαθήματος «Επιστήμη δεδομένων και εφαρμογές» θα απασχοληθούμε με το εξής ερώτημα:
# Πως μπορούμε να προσεγκίσουμε την τιμή μιας μεταβλητής που δεν γνωρίζουμε σε έναν μαθηματικό τύπο που υπολογίζει την θερμοκρασία ενός αστέρα.
#
#
#
# η στρατηγική μας θα είναι η εξής:
#
# 1. Θα δημιουργήσουμε ένα sub-dataset από το survey Gaia για data αστέρων. μεταβλητες:
# * $m$: Apparent magnitude (in Gaia, this is phot_g_mean_mag).
# * $p$: Parallax in milliarcseconds (mas).
#
# * The formula for Absolute Magnitude is:$$M = m + 5 + 5 \log_{10}\left(\frac{p}{1000}\right)$$
#
# Ορίζουμε ως εξαρτημένη μεταβλητή την θερμοκρασία των αστέρων.
#
# 2. Θα ψάξουμε πτιοκοποιήσουμε την εξαρτημένη μεταβλητή (tempreture) σε ένα διάγραμμα με την

# %% [markdown]
# Part 1 — Exploratory Data Analysis

# %% [markdown]
# Πρώτο βήμα στην δημιουργία του sub-dataset ειναι to registration. Δηλώνουμε ποια mods θελουμε να χρησιμοποιήσουμε. Αφού ορίσουμε ποια κομμάτια χρειαζόμαστε, θα κατεβάσουμε με βάση αυτή την λίστα τα επιθυμιτά κομμάτια.

# %%
sample_df = factory.load_as_dataframe("MultimodalUniverse/gaia","train", n_samples=10)
# Out:
# Opening stream to: MultimodalUniverse/gaia...
# Fetched 10 items (Sieved 10 total).

# %%
print("Available columns in this dataset:")
print(type(sample_df), sample_df.columns )
# Out:
# Available columns in this dataset:
# <class 'pandas.core.frame.DataFrame'> Index(['object_id', 'healpix', 'ra', 'dec', 'coeff', 'coeff_error',
#        'phot_g_mean_mag', 'phot_g_mean_flux', 'phot_g_mean_flux_error',
#        'phot_bp_mean_mag', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error',
#        'phot_rp_mean_mag', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error',
#        'phot_bp_rp_excess_factor', 'bp_rp', 'bp_g', 'g_rp', 'ra', 'ra_error',
#        'dec', 'dec_error', 'parallax', 'parallax_error', 'pmra', 'pmra_error',
#        'pmdec', 'pmdec_error', 'ra_dec_corr', 'ra_parallax_corr',
#        'ra_pmra_corr', 'ra_pmdec_corr', 'dec_parallax_corr', 'dec_pmra_corr',
#        'dec_pmdec_corr', 'parallax_pmra_corr', 'parallax_pmdec_corr',
#        'pmra_pmdec_corr', 'radial_velocity', 'radial_velocity_error',
#        'rv_template_fe_h', 'rv_template_logg', 'rv_template_teff',
#        'ag_gspphot', 'ag_gspphot_lower', 'ag_gspphot_upper', 'azero_gspphot',
#        'azero_gspphot_lower', 'azero_gspphot_upper', 'distance_gspphot',
#        'distance_gspphot_lower', 'distance_gspphot_upper', 'ebpminrp_gspphot',
#        'ebpminrp_gspphot_lower', 'ebpminrp_gspphot_upper', 'logg_gspphot',
#        'logg_gspphot_lower', 'logg_gspphot_upper', 'mh_gspphot',
#        'mh_gspphot_lower', 'mh_gspphot_upper', 'teff_gspphot',
#        'teff_gspphot_lower', 'teff_gspphot_upper', 'ruwe', 'ecl_lat',
#        'ecl_lon', 'nu_eff_used_in_astrometry', 'pseudocolour',
#        'astrometric_params_solved', 'rv_template_teff', 'grvs_mag'],
#       dtype='object')

# %%
df = factory.get_streaming_examples("MultimodalUniverse/gaia","train", n_samples=10)
# Out:
# Opening stream to: MultimodalUniverse/gaia...
# Fetched 10 items (Sieved 10 total).

# %%
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2611/1172785014.py in <cell line: 0>()
# ----> 1 df.shape()
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# Test: Peek at raw data values for the keys we are filtering on
print("--- Gaia Stream Diagnostic ---")
ds = factory.get_streaming_examples("MultimodalUniverse/gaia", split='train')
sample_batch = []
it = iter(ds)

for i in range(3):
    item = next(it)
    print(f"\nItem {i} Data:")
    print(f" > 'parallax': {item.get('parallax')} (Type: {type(item.get('parallax'))})")
    print(f" > 'ruwe': {item.get('ruwe')} (Type: {type(item.get('ruwe'))})")
    print(f" > 'phot_g_mean_mag': {item.get('phot_g_mean_mag')}")
    # Check if the keys we used for Legacy Survey even exist here
    print(f" > 'type' exists?: {'type' in item}")
    print(f" > 'shape_r' exists?: {'shape_r' in item}")
# Out:
# --- Gaia Stream Diagnostic ---
# Opening stream to: MultimodalUniverse/gaia...
# Fetched 4 items (Sieved 4 total).
#
# Item 0 Data:
#  > 'parallax': None (Type: <class 'NoneType'>)
#  > 'ruwe': None (Type: <class 'NoneType'>)
#  > 'phot_g_mean_mag': None
#  > 'type' exists?: False
#  > 'shape_r' exists?: False
#
# Item 1 Data:
#  > 'parallax': None (Type: <class 'NoneType'>)
#  > 'ruwe': None (Type: <class 'NoneType'>)
#  > 'phot_g_mean_mag': None
#  > 'type' exists?: False
#  > 'shape_r' exists?: False
#
# Item 2 Data:
#  > 'parallax': None (Type: <class 'NoneType'>)
#  > 'ruwe': None (Type: <class 'NoneType'>)
#  > 'phot_g_mean_mag': None
#  > 'type' exists?: False
#  > 'shape_r' exists?: False

# %%
# Check the root keys of the first item
print(f"Root keys in Gaia item: {ds[0].keys()}")
# Out:
# Root keys in Gaia item: dict_keys(['spectral_coefficients', 'photometry', 'astrometry', 'radial_velocity', 'gspphot', 'flags', 'corrections', 'object_id', 'healpix', 'ra', 'dec'])
